# %% [raw]
# Q1. Create a function which will take a list as an argument and return the product of all the numbers
# after creating a flat list.
#
# Use the below-given list as an argument for your function.
#
# list1 = [1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, {1:34, "key2": [55, 67, 78, 89], 4: (45,22, 61, 34)}, [56, 'data science'], 'Machine Learning']
#
# Note: you must extract numeric keys and values of the dictionary also.

# %%
list1 = [1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, 
         {1:34, "key2": [55, 67, 78, 89], 4: (45,22, 61, 34)}, [56, 'data science'], 
         'Machine Learning']

def list_solver(list1):
    # ------------------DO NOT TOUCH DICT----------------

    mylist = []
    mylist1 = []
    for i in list1:
        if type(i) == dict:
            # print(i)
            for j in i.values():
                # print(j)
                if type(j) == int or type(j) == list or type(j) == tuple:
                    # print(j)
                    mylist.append(j)
            for k in i.keys():
                if type(k) == int:
                    # print(k)
                    mylist.append(k)

    # ------------------DO NOT TOUCH LIST----------------
    mylist2 = []
    for i in list1:
        # print(i)
        if type(i) == list:
            # print(i)
            for j in i:
                if type(j) == int:
                    # print(j)
                    mylist1.append(j)
    # print(mylist1)

    list1 = [1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, 
            {1:34, "key2": [55, 67, 78, 89], 4: (45,22, 61, 34)}, [56, 'data science'], 
            'Machine Learning']

    # ------------------DO NOT TOUCH----------------

    mylist = []
    mylist1 = []
    for i in list1:
        if type(i) == dict:
            # print(i)
            for j in i.values():
                # print(j)
                if type(j) == int or type(j) == list or type(j) == tuple:
                    # print(j)
                    mylist.append(j)
            for k in i.keys():
                if type(k) == int:
                    # print(k)
                    mylist.append(k)
                
                
    # print(mylist)
    for i in mylist:
        if type(i) == list:
            for j in i:
                # print(j)
                mylist1.append(j)
        if type(i) == tuple:
            for k in i:
                # print(k)
                mylist1.append(k)
        if type(i) == int:
            # print(i)
            mylist1.append(i)
            
    # print("It is the dictionary: ", mylist1)

    # ------------------DO NOT TOUCH INT----------------


    mylist3 = []
    for i in list1:
        if type(i) == int:
            # print(i)
            mylist1.append(i)
    # print(mylist1)

    # ------------------DO NOT TOUCH TUPLE----------------


    mylist5 = []

    for i in list1 : 
        if type(i) == tuple:
            for j in i:
                # print(j)
                mylist1.append(j)
    # print(mylist1)

    # ------------------DO NOT TOUCH SET----------------


    for i in list1:
        if type(i) == set:
            # print(i)
            for j in i:
                mylist1.append(j)
    # print(mylist1)

    #---------------DO NOT TOUCH LIST-----------

    for i in list1:
        if type(i) == list:
            for j in i:
                # print(j)
                if type(j) == int:
                    mylist1.append(j)
    print(mylist1)
    from functools import reduce
    a = reduce(lambda x,y : x*y,mylist1)
    print(a)

list_solver(list1)
# Out:
# [34, 55, 67, 78, 89, 45, 22, 61, 34, 1, 4, 1, 2, 3, 4, 34, 56, 78, 89, 34, 1, 2, 3, 44, 55, 66, 56]
# 4134711838987085478833841242112000

# %%
Q2. Write a python program for encrypting a message sent to you by your friend. The logic of encryption
should be such that, for a the output should be z. For b, the output should be y. For c, the output should
be x respectively. Also, the whitespace should be replaced with a dollar sign. Keep the punctuation
marks unchanged.
Input Sentence: I want to become a Data Scientist.
Encrypt the above input sentence using the program you just created.
Note: Convert the given input sentence into lowercase before encrypting. The final output should be
lowercase.

# %%
str1 = input("Enter message for encryption: ")
str2 = str1.lower()
# print(str2)


mylist2 = []
for i in str2:
    if i == " ":
        n = i.replace(" ", "$")
        mylist2.append(n)
    if i == 'a':
        n = i.replace('a', 'z')
        mylist2.append(n)
    if i == 'b':
        n = i.replace('b', 'y')
        mylist2.append(n)
    if i == 'c':
        n = i.replace('c', 'x')
        mylist2.append(n)
    if i == 'd':
        n = i.replace('d', 'w')
        mylist2.append(n)
    if i == 'e':
        n = i.replace('e', 'v')
        mylist2.append(n)
    if i == 'f':
        n = i.replace('f', 'u')
        mylist2.append(n)
    if i == 'g':
        n = i.replace('g', 't')
        mylist2.append(n)
    if i == 'h':
        n = i.replace('h', 's')
        mylist2.append(n)
    if i == 'i':
        n = i.replace('i', 'r')
        mylist2.append(n)
    if i == 'j':
        n = i.replace('j', 'q')
        mylist2.append(n)
    if i == 'k':
        n = i.replace('k', 'p')
        mylist2.append(n)
    if i == 'l':
        n = i.replace('l', 'o')
        mylist2.append(n)
    if i == 'm':
        n = i.replace('m', 'n')
        mylist2.append(n)
    if i == 'n':
        n = i.replace('n', 'm')
        mylist2.append(n)
    if i == 'o':
        n = i.replace('o', 'l')
        mylist2.append(n)
    if i == 'p':
        n = i.replace('p', 'k')
        mylist2.append(n)
    if i == 'q':
        n = i.replace('q', 'j')
        mylist2.append(n)
    if i == 'r':
        n = i.replace('r', 'i')
        mylist2.append(n)
    if i == 's':
        n = i.replace('s', 'h')
        mylist2.append(n)
    if i == 't':
        n = i.replace('t', 'g')
        mylist2.append(n)
    if i == 'u':
        n = i.replace('u', 'f')
        mylist2.append(n)
    if i == 'v':
        n = i.replace('v', 'e')
        mylist2.append(n)
    if i == 'w':
        n = i.replace('w', 'd')
        mylist2.append(n)
    if i == 'x':
        n = i.replace('x', 'c')
        mylist2.append(n)
    if i == 'y':
        n = i.replace('y', 'b')
        mylist2.append(n)
    if i == 'z':
        n = i.replace('z', 'a')
        mylist2.append(n)
        
# print(mylist2)
for i in mylist2:
    print(i,end="")
# Out:
# Enter message for encryption:  Fenil  Modi
# uvmro$$nlwr

# %%
|
